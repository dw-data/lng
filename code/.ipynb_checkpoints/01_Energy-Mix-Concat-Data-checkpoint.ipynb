# %%
# META -- double-check:

# definition: MTU?
# electricity or energy
# generation, production, consumption?

# DATA

# glob all files
# concat files
# regex date / time into different columns + conversion
# group by day/month (or week, needs extracting)
#

# %% [markdown]
# ## Creating large dataset

# %%
import pandas as pd
import glob

# %%
testdf = pd.read_csv('../data/Actual Generation per Production Type_202207200000-202207210000.csv')
testdf.head()
# Out:
#            Area                                             MTU  \
# 0  Austria (AT)  20.07.2022 00:00 - 20.07.2022 00:15 (CET/CEST)
# 1  Austria (AT)  20.07.2022 00:15 - 20.07.2022 00:30 (CET/CEST)
# 2  Austria (AT)  20.07.2022 00:30 - 20.07.2022 00:45 (CET/CEST)
# 3  Austria (AT)  20.07.2022 00:45 - 20.07.2022 01:00 (CET/CEST)
# 4  Austria (AT)  20.07.2022 01:00 - 20.07.2022 01:15 (CET/CEST)
#
#    Biomass  - Actual Aggregated [MW]  \
# 0                                 24
# 1                                 24
# 2                                 24
# 3                                 24
# 4                                 24
#
#   Fossil Brown coal/Lignite  - Actual Aggregated [MW]  \
# 0                                                n/e
# 1                                                n/e
# 2                                                n/e
# 3                                                n/e
# 4                                                n/e
#
# ...

# %%
testdf.columns
# Out:
# Index(['Area', 'MTU', 'Biomass  - Actual Aggregated [MW]',
#        'Fossil Brown coal/Lignite  - Actual Aggregated [MW]',
#        'Fossil Coal-derived gas  - Actual Aggregated [MW]',
#        'Fossil Gas  - Actual Aggregated [MW]',
#        'Fossil Hard coal  - Actual Aggregated [MW]',
#        'Fossil Oil  - Actual Aggregated [MW]',
#        'Fossil Oil shale  - Actual Aggregated [MW]',
#        'Fossil Peat  - Actual Aggregated [MW]',
#        'Geothermal  - Actual Aggregated [MW]',
#        'Hydro Pumped Storage  - Actual Aggregated [MW]',
#        'Hydro Pumped Storage  - Actual Consumption [MW]',
#        'Hydro Run-of-river and poundage  - Actual Aggregated [MW]',
#        'Hydro Water Reservoir  - Actual Aggregated [MW]',
#        'Marine  - Actual Aggregated [MW]', 'Nuclear  - Actual Aggregated [MW]',
#        'Other  - Actual Aggregated [MW]',
#        'Other renewable  - Actual Aggregated [MW]',
# ...

# %%
testdf.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 96 entries, 0 to 95
# Data columns (total 23 columns):
#  #   Column                                                     Non-Null Count  Dtype
# ---  ------                                                     --------------  -----
#  0   Area                                                       96 non-null     object
#  1   MTU                                                        96 non-null     object
#  2   Biomass  - Actual Aggregated [MW]                          96 non-null     int64
#  3   Fossil Brown coal/Lignite  - Actual Aggregated [MW]        96 non-null     object
#  4   Fossil Coal-derived gas  - Actual Aggregated [MW]          96 non-null     object
#  5   Fossil Gas  - Actual Aggregated [MW]                       96 non-null     int64
#  6   Fossil Hard coal  - Actual Aggregated [MW]                 96 non-null     int64
#  7   Fossil Oil  - Actual Aggregated [MW]                       96 non-null     int64
# ...

# %% [markdown]
# ## Reading in all files and creating a big dataset for export

# %%
files = glob.glob('../data/selected_countries/*.csv')

# %%
energymix = pd.DataFrame()

for filename in files:
    df_temp = pd.read_csv(filename)
    energymix = pd.concat([energymix,df_temp],ignore_index=True)
# Out:
# /Users/grueng/.virtualenvs/DW_Data-QfWUG2cH/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3444: DtypeWarning: Columns (19) have mixed types.Specify dtype option on import or set low_memory=False.
#   exec(code_obj, self.user_global_ns, self.user_ns)

# %%
len(energymix)
# Out:
# 911768

# %%
energymix.to_csv('../data/export-selected_countries_dataset.csv', index=False)
